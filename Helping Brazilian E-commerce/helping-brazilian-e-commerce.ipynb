# %% [markdown]
# <div style="background-color:#3b5998; border-radius:2px; border:#000000 solid; padding: 15px; font-size:100%; text-align:center">
#     <h1 align="center" style="color:#ffffff;"><b>HELPING BRAZILIAN E-COMMERCE 💳📦</b></h1>
# </div>

# %% [markdown]
# <div style="background-color:#ffffff; border-radius:2px; border:#000000 solid; padding: 15px; font-size:100%; text-align:center">
#     <img src="https://media.tenor.com/wKlhaRMgF-kAAAAd/malta-malta-gifs.gif" alt="Animated GIF">
# </div>

# %% [markdown]
# <div style="background-color:#dfe3ee; border-radius:2px; border:#000000 solid; padding: 15px; font-size:100%; text-align:center">
#     <h2 align="center" style="color:#000000;"><b>IMPORT DEPENDENCIES</b></h2>
# </div>

# %%
# !pip3 install -q cartopy seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cartopy.crs as ccrs
import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import os
path = '/kaggle/input/brazilian-ecommerce/'
for filename in os.listdir(path):
    print(f"{filename} = pd.read_csv('{os.path.join(path, filename)}')")
# Out:
# olist_customers_dataset.csv = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_customers_dataset.csv')
# olist_sellers_dataset.csv = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_sellers_dataset.csv')
# olist_order_reviews_dataset.csv = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_order_reviews_dataset.csv')
# olist_order_items_dataset.csv = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_order_items_dataset.csv')
# olist_products_dataset.csv = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_products_dataset.csv')
# olist_geolocation_dataset.csv = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_geolocation_dataset.csv')
# product_category_name_translation.csv = pd.read_csv('/kaggle/input/brazilian-ecommerce/product_category_name_translation.csv')
# olist_orders_dataset.csv = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_orders_dataset.csv')
# ...

# %%
olist_customers           = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_customers_dataset.csv')
olist_sellers             = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_sellers_dataset.csv')
olist_order_reviews       = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_order_reviews_dataset.csv')
olist_order_items         = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_order_items_dataset.csv')
olist_products            = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_products_dataset.csv')
olist_geolocation         = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_geolocation_dataset.csv')
product_category          = pd.read_csv('/kaggle/input/brazilian-ecommerce/product_category_name_translation.csv')
olist_orders              = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_orders_dataset.csv')
olist_order_payments      = pd.read_csv('/kaggle/input/brazilian-ecommerce/olist_order_payments_dataset.csv')

# %%
olist_customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
olist_sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
olist_order_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
olist_order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
olist_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
olist_geolocation
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
product_category
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
olist_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
olist_order_payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# <div style="background-color:#dfe3ee; border-radius:2px; border:#000000 solid; padding: 15px; font-size:100%; text-align:center">
#     <h2 align="center" style="color:#000000;"><b>DATA PREPROCESSING</b></h2>
# </div>

# %%
data = pd.merge(olist_customers,olist_orders, on="customer_id", how='inner')
data = data.merge(olist_order_reviews, on="order_id", how='inner')
data = data.merge(olist_order_items, on="order_id", how='inner')
data = data.merge(olist_products, on="product_id", how='inner')
data = data.merge(olist_order_payments, on="order_id", how='inner')
data = data.merge(olist_sellers, on='seller_id', how='inner')
data = data.merge(product_category, on='product_category_name', how='inner')
data.shape
# Out:
# (115609, 40)

# %%
data.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state', 'order_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp', 'order_item_id',
#        'product_id', 'seller_id', 'shipping_limit_date', 'price',
#        'freight_value', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'payment_sequential', 'payment_type', 'payment_installments',
#        'payment_value', 'seller_zip_code_prefix', 'seller_city',
#        'seller_state', 'product_category_name_english'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# customer_id                           0
# customer_unique_id                    0
# customer_zip_code_prefix              0
# customer_city                         0
# customer_state                        0
# order_id                              0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    14
# order_delivered_carrier_date       1195
# order_delivered_customer_date      2400
# order_estimated_delivery_date         0
# review_id                             0
# review_score                          0
# review_comment_title             101808
# review_comment_message            66703
# review_creation_date                  0
# review_answer_timestamp               0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# ...

# %%
data.dropna(subset= ['order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date'], inplace=True)

# %%
data.isnull().sum()
# Out:
# customer_id                          0
# customer_unique_id                   0
# customer_zip_code_prefix             0
# customer_city                        0
# customer_state                       0
# order_id                             0
# order_status                         0
# order_purchase_timestamp             0
# order_approved_at                    0
# order_delivered_carrier_date         0
# order_delivered_customer_date        0
# order_estimated_delivery_date        0
# review_id                            0
# review_score                         0
# review_comment_title             99701
# review_comment_message           65835
# review_creation_date                 0
# review_answer_timestamp              0
# order_item_id                        0
# product_id                           0
# seller_id                            0
# shipping_limit_date                  0
# price                                0
# freight_value                        0
# ...

# %%
data[['product_weight_g','product_length_cm', 'product_height_cm', 'product_width_cm']][data.product_weight_g.isna()]
# Out:
#        product_weight_g  product_length_cm  product_height_cm  \
# 27352               NaN                NaN                NaN
#
#        product_width_cm
# 27352               NaN

# %%
data.drop(27352, inplace=True)
data.reset_index(inplace= True, drop= True)

# %%
data.isnull().sum()
# Out:
# customer_id                          0
# customer_unique_id                   0
# customer_zip_code_prefix             0
# customer_city                        0
# customer_state                       0
# order_id                             0
# order_status                         0
# order_purchase_timestamp             0
# order_approved_at                    0
# order_delivered_carrier_date         0
# order_delivered_customer_date        0
# order_estimated_delivery_date        0
# review_id                            0
# review_score                         0
# review_comment_title             99700
# review_comment_message           65834
# review_creation_date                 0
# review_answer_timestamp              0
# order_item_id                        0
# product_id                           0
# seller_id                            0
# shipping_limit_date                  0
# price                                0
# freight_value                        0
# ...

# %%
data['review_comment_title'].fillna('No Review Title',inplace=True)
data['review_comment_message'].fillna('No Review Message',inplace=True)

# %%
data.isnull().sum()
# Out:
# customer_id                      0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# order_id                         0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# review_id                        0
# review_score                     0
# review_comment_title             0
# review_comment_message           0
# review_creation_date             0
# review_answer_timestamp          0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# product_category_name            0
# product_name_lenght              0
# product_description_lenght       0
# ...

# %%
def classify_cat(x):
    categories = {
        'Furniture': ['office_furniture', 'furniture_decor', 'furniture_living_room', 'kitchen_dining_laundry_garden_furniture', 'bed_bath_table', 'home_comfort', 'home_comfort_2', 'home_construction', 'garden_tools', 'furniture_bedroom', 'furniture_mattress_and_upholstery'],
        'Electronics': ['auto', 'computers_accessories', 'musical_instruments', 'consoles_games', 'watches_gifts', 'air_conditioning', 'telephony', 'electronics', 'fixed_telephony', 'tablets_printing_image', 'computers', 'small_appliances_home_oven_and_coffee', 'small_appliances', 'audio', 'signaling_and_security', 'security_and_services'],
        'Fashion': ['fashio_female_clothing', 'fashion_male_clothing', 'fashion_bags_accessories', 'fashion_shoes', 'fashion_sport', 'fashion_underwear_beach', 'fashion_childrens_clothes', 'baby', 'cool_stuff'],
        'Home & Garden': ['housewares', 'home_confort', 'home_appliances', 'home_appliances_2', 'flowers', 'costruction_tools_garden', 'garden_tools', 'construction_tools_lights', 'costruction_tools_tools', 'luggage_accessories', 'la_cuisine', 'pet_shop', 'market_place'],
        'Entertainment': ['sports_leisure', 'toys', 'cds_dvds_musicals', 'music', 'dvds_blu_ray', 'cine_photo', 'party_supplies', 'christmas_supplies', 'arts_and_craftmanship', 'art'],
        'Beauty & Health': ['health_beauty', 'perfumery', 'diapers_and_hygiene'],
        'Food & Drinks': ['food_drink', 'drinks', 'food'],
        'Books & Stationery': ['books_general_interest', 'books_technical', 'books_imported', 'stationery'],
        'Industry & Construction': ['construction_tools_construction', 'construction_tools_safety', 'industry_commerce_and_business', 'agro_industry_and_commerce']
    }
    for category, keywords in categories.items():
        if x in keywords:
            return category
    return None

data['product_category'] = data['product_category_name_english'].apply(classify_cat)

# %%
data['product_category'].value_counts()
# Out:
# product_category
# Electronics                29568
# Furniture                  28050
# Entertainment              13507
# Beauty & Health            13283
# Home & Garden              12848
# Fashion                     9722
# Books & Stationery          3427
# Industry & Construction     1633
# Food & Drinks               1155
# Name: count, dtype: int64

# %%
# Create Volume Column
data['product_vol_cm3'] = data['product_length_cm'] * data['product_width_cm'] * data['product_height_cm']
# Drop Width, Height and Length
data.drop(columns=['product_length_cm', 'product_width_cm', 'product_height_cm'],inplace= True)

# %%
data['order_purchase_timestamp']      = pd.to_datetime(data['order_purchase_timestamp'],errors='coerce')
data['order_delivered_customer_date'] = pd.to_datetime(data['order_delivered_customer_date'],errors='coerce')
data['order_estimated_delivery_date'] = pd.to_datetime(data['order_estimated_delivery_date'],errors='coerce')
data['shipping_limit_date']           = pd.to_datetime(data['shipping_limit_date'],errors='coerce')
data['order_delivered_carrier_date']  = pd.to_datetime(data['order_delivered_carrier_date'],errors='coerce')

# %%
# Extract duration of estimated shipping from purchasing date untill estimated delivery date
data['estimated_days']   = (data['order_estimated_delivery_date'] - data['order_purchase_timestamp']).dt.days
# Extract duration of shipping from purchasing date until delivered to customer date
data['arrival_days']     = (data['order_delivered_customer_date'] - data['order_purchase_timestamp']).dt.days
# Extract duration of shipping from purchasing carrier delivered date untill delivered to customer
data['shipping_days']    = (data['order_delivered_customer_date'] - data['order_delivered_carrier_date']).dt.days

# %%
# Drop inconsistent dates where "order_delivered_carrier_date" is greater than "order_delivered_customer_date"
data.drop((data[['order_delivered_carrier_date', 'order_delivered_customer_date']][data.shipping_days < 0]).index, inplace= True)

# %%
# Shipping stat  S <-> C
# First get seller to carrier duration in days and classify the duration into 'OnTime/Early' & 'Late'
data['seller_to_carrier_status'] = np.where((data['shipping_limit_date'] - data['order_delivered_carrier_date']).dt.days >= 0, 'OnTime/Early', 'Late')
# First get difference between estimated delivery date and actual delivery date in days and classify the duration in 'OnTime/Early' & 'Late'
data['arrival_status']           = np.where((data['order_estimated_delivery_date'] - data['order_delivered_customer_date']).dt.days >= 0, 'OnTime/Early', 'Late')

# %%
# Remove Outliers
# Create a boolean mask for the outliers
mask = (data['estimated_days'] <= 60) & (data['arrival_days'] <= 60) & (data['shipping_days'] <= 60)
# Filter the data to keep only the rows that meet the condition
data = data[mask]
# Reset the index of the dataframe
data.reset_index(drop=True, inplace=True)

# %%
def rates(x):
    if x < 8:
        return 'Very Fast'
    elif x < 16:
        return 'Fast'
    elif x < 25:
        return 'Neutral'
    elif x < 40:
        return 'Slow'
    else:
        return 'Very Slow'
data['estimated_delivery_rate'] = data['estimated_days'].apply(rates)
data['arrival_delivery_rate'] = data['arrival_days'].apply(rates)
data['shipping_delivery_rate'] = data['shipping_days'].apply(rates)

# %%
data
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 2       8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
# 3       f0ac8e5a239118859b1734e1087cbb1f  3c799d181c34d51f6d44bbbc563024db
# 4       6bc8d08963a135220ed6c6d098831f84  23397e992b09769faf5e66f9e171a241
# ...                                  ...                               ...
# 112562  e548277911829ffe81aac2b4407de701  a0abd26659c9914690cbd3320d39fd96
# 112563  0fbd856ba1d4961786fb54bd448eb7fe  96328ac15f58fbb232fe14b182103382
# 112564  aa0533eb31ed3be79086f11bb2bec430  a490d5875edefe9bb8f5101ec2f6b56f
# 112565  d11524bb77c28efad04e4467eac8a660  6968d41eb700f1ea39424e04b854bf7e
# 112566  d11524bb77c28efad04e4467eac8a660  6968d41eb700f1ea39424e04b854bf7e
#
# ...

# %% [markdown]
# <div style="background-color:#dfe3ee; border-radius:2px; border:#000000 solid; padding: 15px; font-size:100%; text-align:center">
#     <h2 align="center" style="color:#000000;"><b>DATA ANALYSIS</b></h2>
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112567 entries, 0 to 112566
# Data columns (total 47 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    112567 non-null  object
#  1   customer_unique_id             112567 non-null  object
#  2   customer_zip_code_prefix       112567 non-null  int64
#  3   customer_city                  112567 non-null  object
#  4   customer_state                 112567 non-null  object
#  5   order_id                       112567 non-null  object
#  6   order_status                   112567 non-null  object
#  7   order_purchase_timestamp       112567 non-null  datetime64[ns]
#  8   order_approved_at              112567 non-null  object
#  9   order_delivered_carrier_date   112567 non-null  datetime64[ns]
#  10  order_delivered_customer_date  112567 non-null  datetime64[ns]
# ...

# %%
data.describe().T
# Out:
#                                   count                           mean  \
# customer_zip_code_prefix       112567.0                   35040.369655
# order_purchase_timestamp         112567  2018-01-01 20:25:29.138184704
# order_delivered_carrier_date     112567  2018-01-05 02:02:53.051657984
# order_delivered_customer_date    112567  2018-01-14 01:25:29.121696256
# order_estimated_delivery_date    112567  2018-01-25 13:25:14.522018048
# review_score                   112567.0                       4.088472
# order_item_id                  112567.0                       1.194764
# shipping_limit_date              112567  2018-01-08 09:34:06.237191936
# price                          112567.0                     119.687366
# freight_value                  112567.0                      19.956023
# product_name_lenght            112567.0                      48.806178
# product_description_lenght     112567.0                      784.71481
# ...

# %%
plt.figure(figsize=[10, 6])
sns.barplot(x = data['customer_city'].value_counts().values[:10], y = data['customer_city'].value_counts().index[:10], palette='Set2')
plt.title('Top 10 Customers Capacity Cities')
sns.despine()

# %%
plt.figure(figsize=[10, 6])
sns.barplot(x = data['customer_state'].value_counts().values[:10], y = data['customer_state'].value_counts().index[:10], palette= 'Set2')
plt.title('Top 10 Customers Capacity States')
sns.despine()

# %%
data['order_status'].value_counts()
# Out:
# order_status
# delivered    112560
# canceled          7
# Name: count, dtype: int64

# %%
data.drop('order_status', axis=1, inplace=True)

# %%
plt.figure(figsize=[15, 8])
review_score_index = [str(i) for i in data['review_score'].value_counts().index]
sns.barplot(x = review_score_index, y= data['review_score'].value_counts().values, palette= 'Set2')
plt.title('Review Scores')
sns.despine()

# %%
plt.figure(figsize=[10, 6])
sns.barplot(x = data['product_category'].value_counts().values, y = data['product_category'].value_counts().index, palette= 'Set2')
plt.title('Number of orders per each Category')
plt.xticks(rotation = 45)
sns.despine()

# %%
plt.figure(figsize=[10, 6])
sns.countplot(x = data['product_photos_qty'], palette= 'Set2')
plt.title('Product Photos Quantity')
sns.despine()

# %%
plt.figure(figsize=[10, 6])
sns.set_palette('Set2')
sns.distplot(x = data['price'])
plt.title('Price Distribution')
sns.despine()

# %%
plt.figure(figsize=[10, 6])
sns.set_palette('Set2')
sns.distplot(x = data['freight_value'])
plt.title('Freight Value Distribution')
sns.despine()

# %%
plt.figure(figsize=[10, 6])
sns.distplot(x = data['product_name_lenght'])
plt.title('Product Name Length')
data['product_category'].value_counts().values
# Out:
# array([29453, 27791, 13451, 13224, 12780,  9680,  3412,  1630,  1146])

# %%
plt.figure(figsize=[10, 6])
sns.distplot(x = data['product_description_lenght'])
plt.title('Product Describtion Length')
sns.despine()

# %%
plt.figure(figsize=[10, 6])
sns.distplot(x = data['product_weight_g'])
plt.title('Product Weight')
sns.despine()

# %%
plt.figure(figsize=[10, 6])
sns.distplot(x = data['product_vol_cm3'])
plt.title('Product Volume')
sns.despine()

# %%
plt.figure(figsize=[10, 6])
sns.distplot(x = data['payment_value'])
plt.title('Payment Value')
sns.despine()

# %%
plt.figure(figsize=[10, 10])
plt.pie(data['payment_type'].value_counts().values,
        explode=(0.05, 0.05, 0.05, 0.05),
        labels= data['payment_type'].value_counts().index,
        autopct='%1.1f%%',
        shadow=False,
        startangle=90
       );

# %%
data['payment_installments'].value_counts()
# Out:
# payment_installments
# 1     56130
# 2     13095
# 3     11259
# 4      7646
# 10     6576
# 5      5779
# 8      4844
# 6      4417
# 7      1723
# 9       685
# 12      157
# 15       85
# 18       38
# 24       34
# 11       22
# 20       19
# 13       18
# 14       15
# 17        7
# 16        7
# 21        6
# 0         3
# 23        1
# 22        1
# Name: count, dtype: int64

# %%
data[data['payment_installments'] == 0]
# Out:
#                             customer_id                customer_unique_id  \
# 28837  48ebb06cf56dba9d009230cc751bb195  9925e1d7dff0d807355599dee04830ab
# 28838  48ebb06cf56dba9d009230cc751bb195  9925e1d7dff0d807355599dee04830ab
# 96161  5e5794daaa13f73e2f1cdb4114529843  f54cea27c80dc09bfe07b1cf1e01b845
#
#        customer_zip_code_prefix     customer_city customer_state  \
# 28837                     44001  feira de santana             BA
# 28838                     44001  feira de santana             BA
# 96161                      5263         sao paulo             SP
#
#                                order_id order_purchase_timestamp  \
# 28837  1a57108394169c0b47d8f876acc9ba2d      2018-05-15 16:25:14
# 28838  1a57108394169c0b47d8f876acc9ba2d      2018-05-15 16:25:14
# 96161  744bade1fcf9ff3f31d860ace076d422      2018-04-22 11:34:42
#
#          order_approved_at order_delivered_carrier_date  \
# 28837  2018-05-15 16:36:52          2018-05-17 12:37:00
# ...

# %%
# Drop indices
data.drop([29113, 29114, 96733], inplace=True)
# Reset Index
data.reset_index(inplace= True, drop= True)

# %%
plt.figure(figsize=[10, 6])
sns.countplot(x = data['payment_installments'], palette= 'Set2')
plt.title('Installments Distribution')
sns.despine()

# %%
plt.figure(figsize=[10, 6])
sns.barplot(x = data['seller_city'].value_counts().values[:10], y= data['seller_city'].value_counts().index[:10], palette= 'Set2')
plt.title('Top 10 Sellers Cities')
sns.despine()

# %%
plt.figure(figsize=[15, 8])
sns.barplot(x = data['seller_state'].value_counts().values[:10], y= data['seller_state'].value_counts().index[:10], palette= 'Set2')
plt.title('Top 10 Sellers States')
sns.despine()

# %%
# Group customer city by payment value
revenue_per_city = data.groupby('customer_city')[['payment_value']].sum().sort_values(by='payment_value', ascending=False)
revenue_per_city.reset_index(inplace=True)
# plot Top 10 cities with highest revenue
plt.figure(figsize=[15, 8])
sns.barplot(x = revenue_per_city.customer_city[:10], y= revenue_per_city.payment_value[:10], palette= 'Set2')
plt.title('Top 10 Cities with highest Revenue', fontsize= 15)
plt.xlabel('Customer City', fontsize= 12)
plt.ylabel('Total Payments in Millions',fontsize= 12)
sns.despine()

# %%
# Filter product category with 4.5 or above
review_per_cat = data.groupby('product_category')[['review_score']].mean().sort_values(by='review_score', ascending=False)
review_per_cat.reset_index(inplace=True)
# Plot Product Category vs Review Score
plt.figure(figsize=[15, 8])
sns.barplot(x = review_per_cat.review_score, y= review_per_cat.product_category, palette= 'Set2')
plt.title('Average Review Score per Product Category', fontsize= 15)
plt.xlabel('Review Score', fontsize=12)
plt.ylabel('Prodcut Category', fontsize= 12)
ax = plt.gca()
ax.set_frame_on(False);

# %%
# Group each payment type by average payment value
payment_methods = data.groupby('payment_type')[['payment_value']].sum().sort_values(by='payment_value', ascending=False)
payment_methods.reset_index(inplace=True)
# plot Average payments per payment method
plt.figure(figsize=[15, 8])
sns.barplot(x = payment_methods.payment_type, y= payment_methods.payment_value, palette= 'Set2')
plt.title('Total Revenue per payment method', fontsize= 15)
plt.xlabel('Payment Type', fontsize= 12)
plt.ylabel('Revenue per Payment type (Millions)', fontsize= 12)
sns.despine()

# %%
# Group each payment type by average payment value
payment_methods = data.groupby('payment_type')[['payment_value']].mean().sort_values(by='payment_value', ascending=False)
payment_methods.reset_index(inplace=True)
# plot Average payments per payment method
plt.figure(figsize=[15, 8])
sns.barplot(x = payment_methods.payment_type, y= payment_methods.payment_value, palette= 'Set2')
plt.title('Average payment value per payment method', fontsize= 15)
plt.xlabel('Payment Type', fontsize= 12)
plt.ylabel('Average Payment Value', fontsize= 12)
sns.despine()

# %%
# Group product category by average freight value
freight_per_cat = data.groupby('product_category')[['freight_value']].mean().sort_values(by='freight_value', ascending=False)
freight_per_cat.reset_index(inplace=True)
# plot average freight value per product category
plt.figure(figsize=[15, 8])
sns.barplot(x = freight_per_cat.freight_value, y=  freight_per_cat.product_category, palette= 'Set2')
plt.title('Average Freight Value per Product Category', fontsize= 15)
plt.xlabel('Average Freight Value',fontsize= 12)
plt.ylabel('Product Category', fontsize= 12)
ax = plt.gca()
ax.set_frame_on(False);

# %%
# Group product category by average arrival time
ship_per_cat = data.groupby('product_category')[['arrival_days']].mean().sort_values(by='arrival_days', ascending=False)
ship_per_cat.reset_index(inplace=True)

# plot average freight value per product category
plt.figure(figsize=[15, 8])
sns.barplot(x = ship_per_cat.arrival_days, y=  ship_per_cat.product_category, palette= 'Set2')
plt.title('Average arrival Time per Product Category', fontsize= 15)
plt.xlabel('Average arrival time (days)',fontsize= 12)
plt.ylabel('Product Category', fontsize= 12)
ax = plt.gca()
ax.set_frame_on(False);

# %%
plt.figure(figsize=[15, 8])
voucher_trans = data[data.payment_type == 'voucher']
sns.countplot(x= voucher_trans.review_score)
# Out:
# <Axes: xlabel='review_score', ylabel='count'>

# %%
plt.figure(figsize=[30,8])
Values = data.arrival_status.value_counts().values
Labels = data.arrival_status.value_counts().index
plt.pie(Values, explode=(0.05, 0.05), labels= ['OnTime/Early', 'Late'], autopct='%1.1f%%', shadow=True);

# %%
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.Robinson()})
ax.coastlines()
lon, lat = olist_geolocation['geolocation_lng'].to_numpy(), olist_geolocation['geolocation_lat'].to_numpy()
ax.plot(lon, lat, 'o', markersize=5, color='red', transform=ccrs.PlateCarree())
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
plt.show()

# %%
plt.figure(figsize=[15, 8])
sns.scatterplot(x = olist_geolocation['geolocation_lng'], y = olist_geolocation['geolocation_lat'], hue= data['product_category'])
plt.title('Distribution Of Categories by location', fontsize= 15)
plt.xlabel('Longitude',fontsize= 12)
plt.ylabel('Latitude', fontsize= 12)
ax = plt.gca()
ax.set_frame_on(False);sns.despine()

# %% [markdown]
# <div style="background-color:#ffffff; border-radius:2px; border:#000000 solid; padding: 15px; font-size:100%; text-align:center">
#     <img src="https://media.tenor.com/Q823-830Ri0AAAAd/christian-bale-american-psycho.gif" alt="Animated GIF">
# </div>
