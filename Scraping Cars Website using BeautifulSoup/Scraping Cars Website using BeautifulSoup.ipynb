# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ### HTTP Request

# %% [markdown]
# #### store website in variable

# %%
website = 'https://www.cars.com/shopping/results/?stock_type=cpo&makes%5B%5D=mercedes_benz&models%5B%5D=&list_price_max=&maximum_distance=20&zip='

# %% [markdown]
# #### Get Request

# %%
response = requests.get(website)

# %% [markdown]
# #### Status Code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ### Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# ### Results

# %%
results = soup.find_all('div', {'class' : 'vehicle-card'})

# %%
len(results)
# Out:
# 21

# %% [markdown]
# ### Target necessary data

# %%
# Name
# Mileage
# Dealer Name
# Rating
# Rating Count
# Price

# %% [markdown]
# #### Name

# %%
results[0].find('h2').get_text()
# Out:
# '2020 Mercedes-Benz AMG C 43 Base 4MATIC'

# %% [markdown]
# #### Mileage

# %%
results[0].find('div', {'class':'mileage'}).get_text()
# Out:
# '29,790 mi.'

# %% [markdown]
# #### Dealer Name

# %%
results[0].find('div', {'class':'dealer-name'}).get_text().strip()
# Out:
# 'Mercedes-Benz of Kansas City'

# %% [markdown]
# #### Rating

# %%
rating_count_element = results[0].find('span', {'class': 'sds-rating__count'})
rating_count = rating_count_element.get_text() if rating_count_element else "N/A"

# %% [markdown]
# #### Review Count

# %%
rating_link_element = results[0].find('span', {'class': 'sds-rating__link'})
rating_link = rating_link_element.get_text() if rating_link_element else "N/A"

# %% [markdown]
# #### Price

# %%
results[0].find('span', {'class':'primary-price'}).get_text()
# Out:
# '$47,698'

# %% [markdown]
# ### Put everything together inside a For-Loop

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for result in results:
    
    # name
    try:
        name.append(result.find('h2').get_text()) 
    except:
        name.append('n/a')
    
    # mileage
    try:
        mileage.append(result.find('div', {'class':'mileage'}).get_text())
    except:
        mileage.append('n/a')
    
    # dealer_name
    try:
        dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
    except:
        dealer_name.append('n/a')
        
    # rating
    try:
        rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
    except:
        rating.append('n/a')
    
    # review_count
    try:
        review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
    except:
        review_count.append('n/a')
    
    #price 
    try:
        price.append(result.find('span', {'class':'primary-price'}).get_text())
    except:
        price.append('n/a')

# %% [markdown]
# ### Create Pandas Dataframe

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,
                                'Rating': rating, 'Review Count': review_count, 'Price': price})

# %%
car_dealer
# Out:
#                                             Name     Mileage  \
# 0        2020 Mercedes-Benz AMG C 43 Base 4MATIC  29,790 mi.
# 1         2020 Mercedes-Benz GLS 450 Base 4MATIC  38,260 mi.
# 2              2023 Mercedes-Benz GLS 450 4MATIC  10,456 mi.
# 3          2019 Mercedes-Benz AMG GT 63 S 4-Door   4,321 mi.
# 4          2020 Mercedes-Benz GLE 580 AWD 4MATIC  33,365 mi.
# 5        2021 Mercedes-Benz AMG C 43 Base 4MATIC  18,182 mi.
# 6        2023 Mercedes-Benz AMG C 43 Base 4MATIC   2,410 mi.
# 7        2019 Mercedes-Benz A-Class A 220 4MATIC  28,983 mi.
# 8        2023 Mercedes-Benz AMG C 43 Base 4MATIC     799 mi.
# 9         2022 Mercedes-Benz GLE 350 Base 4MATIC  18,335 mi.
# 10               2022 Mercedes-Benz GLE 350 Base  14,449 mi.
# 11       2020 Mercedes-Benz AMG E 53 Base 4MATIC  41,938 mi.
# 12  2021 Mercedes-Benz AMG GLE 63 S-Model 4MATIC  13,038 mi.
# 13       2023 Mercedes-Benz E-Class E 450 4MATIC   1,565 mi.
# 14        2023 Mercedes-Benz GLE 350 Base 4MATIC  10,452 mi.
# 15       2021 Mercedes-Benz E-Class E 450 4MATIC   9,368 mi.
# 16       2023 Mercedes-Benz E-Class E 450 4MATIC   9,200 mi.
# 17        2023 Mercedes-Benz EQB 350 Base 4MATIC   5,216 mi.
# 18       2020 Mercedes-Benz AMG C 43 Base 4MATIC  29,819 mi.
# 19     2020 Mercedes-Benz AMG GLC 43 Base 4MATIC  30,219 mi.
# 20     2021 Mercedes-Benz AMG GLS 63 Base 4MATIC  15,517 mi.
#
#                                           Dealer Name Rating     Review Count  \
# 0                        Mercedes-Benz of Kansas City    n/a              n/a
# 1                       Mercedes-Benz of White Plains    4.3  (1,647 reviews)
# 2                      Mercedes-Benz of Silver Spring    4.9  (2,002 reviews)
# 3                    Mercedes-Benz of Hoffman Estates    4.6  (1,210 reviews)
# 4                         Mercedes-Benz of Manchester    4.4    (761 reviews)
# 5                             Mercedes-Benz of Edison    5.0  (4,416 reviews)
# 6                        Mercedes-Benz of Hunt Valley    4.7    (771 reviews)
# 7                          Mercedes-Benz of Arrowhead    2.7    (235 reviews)
# 8                         Mercedes-Benz of Barrington    4.8    (488 reviews)
# 9                         Mercedes-Benz of Barrington    4.8    (488 reviews)
# 10                        Mercedes-Benz of Barrington    4.8    (488 reviews)
# 11                                 Silver Star Motors    4.4    (848 reviews)
# 12                           Mercedes-Benz of Wichita    n/a    (110 reviews)
# 13                   Mercedes-Benz of Hoffman Estates    4.6  (1,210 reviews)
# 14  Mercedes-Benz of San Francisco / Smart Center ...    n/a     (62 reviews)
# 15                    Mercedes-Benz of Fredericksburg    4.7    (442 reviews)
# 16                      Mercedes-Benz of Walnut Creek    4.3  (1,060 reviews)
# 17                           Mercedes-Benz of Chicago    4.8  (1,342 reviews)
# 18                                  Serra Auto Campus    3.3     (44 reviews)
# 19                      Mercedes-Benz of Owings Mills    4.9  (2,331 reviews)
# 20                        Mercedes-Benz of Louisville    4.4    (992 reviews)
#
#        Price
# 0    $47,698
# 1    $54,924
# 2    $83,900
# 3   $125,999
# 4    $56,989
# 5    $54,599
# 6    $60,479
# 7    $25,988
# 8    $62,955
# 9    $56,999
# 10   $54,250
# 11   $53,550
# 12   $95,998
# 13   $69,999
# 14   $58,807
# 15   $66,000
# 16   $66,286
# 17   $55,991
# 18   $47,021
# 19   $47,900
# 20  $100,541

# %% [markdown]
# #### Data Cleaning

# %%
car_dealer['Review Count'] = car_dealer['Review Count'].apply(lambda x: x.strip('reviews)').strip('('))

# %%
# dataframe updated
car_dealer
# Out:
#                                             Name     Mileage  \
# 0        2020 Mercedes-Benz AMG C 43 Base 4MATIC  29,790 mi.
# 1         2020 Mercedes-Benz GLS 450 Base 4MATIC  38,260 mi.
# 2              2023 Mercedes-Benz GLS 450 4MATIC  10,456 mi.
# 3          2019 Mercedes-Benz AMG GT 63 S 4-Door   4,321 mi.
# 4          2020 Mercedes-Benz GLE 580 AWD 4MATIC  33,365 mi.
# 5        2021 Mercedes-Benz AMG C 43 Base 4MATIC  18,182 mi.
# 6        2023 Mercedes-Benz AMG C 43 Base 4MATIC   2,410 mi.
# 7        2019 Mercedes-Benz A-Class A 220 4MATIC  28,983 mi.
# 8        2023 Mercedes-Benz AMG C 43 Base 4MATIC     799 mi.
# 9         2022 Mercedes-Benz GLE 350 Base 4MATIC  18,335 mi.
# 10               2022 Mercedes-Benz GLE 350 Base  14,449 mi.
# 11       2020 Mercedes-Benz AMG E 53 Base 4MATIC  41,938 mi.
# 12  2021 Mercedes-Benz AMG GLE 63 S-Model 4MATIC  13,038 mi.
# 13       2023 Mercedes-Benz E-Class E 450 4MATIC   1,565 mi.
# 14        2023 Mercedes-Benz GLE 350 Base 4MATIC  10,452 mi.
# 15       2021 Mercedes-Benz E-Class E 450 4MATIC   9,368 mi.
# 16       2023 Mercedes-Benz E-Class E 450 4MATIC   9,200 mi.
# 17        2023 Mercedes-Benz EQB 350 Base 4MATIC   5,216 mi.
# 18       2020 Mercedes-Benz AMG C 43 Base 4MATIC  29,819 mi.
# 19     2020 Mercedes-Benz AMG GLC 43 Base 4MATIC  30,219 mi.
# 20     2021 Mercedes-Benz AMG GLS 63 Base 4MATIC  15,517 mi.
#
#                                           Dealer Name Rating Review Count  \
# 0                        Mercedes-Benz of Kansas City    n/a          n/a
# 1                       Mercedes-Benz of White Plains    4.3       1,647
# 2                      Mercedes-Benz of Silver Spring    4.9       2,002
# 3                    Mercedes-Benz of Hoffman Estates    4.6       1,210
# 4                         Mercedes-Benz of Manchester    4.4         761
# 5                             Mercedes-Benz of Edison    5.0       4,416
# 6                        Mercedes-Benz of Hunt Valley    4.7         771
# 7                          Mercedes-Benz of Arrowhead    2.7         235
# 8                         Mercedes-Benz of Barrington    4.8         488
# 9                         Mercedes-Benz of Barrington    4.8         488
# 10                        Mercedes-Benz of Barrington    4.8         488
# 11                                 Silver Star Motors    4.4         848
# 12                           Mercedes-Benz of Wichita    n/a         110
# 13                   Mercedes-Benz of Hoffman Estates    4.6       1,210
# 14  Mercedes-Benz of San Francisco / Smart Center ...    n/a          62
# 15                    Mercedes-Benz of Fredericksburg    4.7         442
# 16                      Mercedes-Benz of Walnut Creek    4.3       1,060
# 17                           Mercedes-Benz of Chicago    4.8       1,342
# 18                                  Serra Auto Campus    3.3          44
# 19                      Mercedes-Benz of Owings Mills    4.9       2,331
# 20                        Mercedes-Benz of Louisville    4.4         992
#
#        Price
# 0    $47,698
# 1    $54,924
# 2    $83,900
# 3   $125,999
# 4    $56,989
# 5    $54,599
# 6    $60,479
# 7    $25,988
# 8    $62,955
# 9    $56,999
# 10   $54,250
# 11   $53,550
# 12   $95,998
# 13   $69,999
# 14   $58,807
# 15   $66,000
# 16   $66,286
# 17   $55,991
# 18   $47,021
# 19   $47,900
# 20  $100,541

# %% [markdown]
# ### Output in Excel

# %%
# !pip3 install openpyxl
car_dealer.to_excel('./assets/car_dealer_single_page.xlsx', index=False)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in /home/hussein-ali/.local/lib/python3.8/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /home/hussein-ali/.local/lib/python3.8/site-packages (from openpyxl) (1.1.0)

# %% [markdown]
# ### Part 2 - Pagination

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for i in range (1,11):
    
    # website in variable
    website = 'https://www.cars.com/shopping/results/?page='+ str(i) +'&page_size=20&dealer_id=&list_price_max=&list_price_min=&makes[]=mercedes_benz&maximum_distance=20&mileage_max=&sort=best_match_desc&stock_type=cpo&year_max=&year_min=&zip=' 
    
    # request to website
    response = requests.get(website)
    
    # soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # results
    results = soup.find_all('div', {'class' : 'vehicle-card'})
    
    # loop through results
    for result in results:
    
        # name
        try:
            name.append(result.find('h2').get_text()) 
        except:
            name.append('n/a')

        # mileage
        try:
            mileage.append(result.find('div', {'class':'mileage'}).get_text())
        except:
            mileage.append('n/a')

        # dealer_name
        try:
            dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
        except:
            dealer_name.append('n/a')

        # rating
        try:
            rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
        except:
            rating.append('n/a')

        # review_count
        try:
            review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
        except:
            review_count.append('n/a')

        #price 
        try:
            price.append(result.find('span', {'class':'primary-price'}).get_text())
        except:
            price.append('n/a')

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,
                                'Rating': rating, 'Review Count': review_count, 'Price': price})

# %%
car_dealer
# Out:
#                                         Name     Mileage  \
# 0    2020 Mercedes-Benz AMG C 43 Base 4MATIC  29,790 mi.
# 1          2023 Mercedes-Benz GLS 450 4MATIC  10,456 mi.
# 2     2020 Mercedes-Benz GLS 450 Base 4MATIC  38,260 mi.
# 3      2019 Mercedes-Benz AMG GT 63 S 4-Door   4,321 mi.
# 4    2021 Mercedes-Benz AMG C 43 Base 4MATIC  18,182 mi.
# ..                                       ...         ...
# 205         2022 Mercedes-Benz A-Class A 220  12,678 mi.
# 206       2023 Mercedes-Benz AMG GLB 35 Base   4,048 mi.
# 207       2023 Mercedes-Benz AMG GLB 35 Base   3,166 mi.
# 208  2023 Mercedes-Benz AMG C 43 Base 4MATIC   2,585 mi.
# 209    2021 Mercedes-Benz GLE 580 AWD 4MATIC  12,654 mi.
#
#                           Dealer Name Rating     Review Count     Price
# 0        Mercedes-Benz of Kansas City    n/a              n/a   $47,698
# 1      Mercedes-Benz of Silver Spring    4.9  (2,002 reviews)   $83,900
# 2       Mercedes-Benz of White Plains    4.3  (1,647 reviews)   $54,924
# 3    Mercedes-Benz of Hoffman Estates    4.6  (1,210 reviews)  $125,999
# 4             Mercedes-Benz of Edison    5.0  (4,416 reviews)   $54,599
# ..                                ...    ...              ...       ...
# 205     Mercedes-Benz of West Houston    4.6     (75 reviews)   $33,893
# 206        Mercedes-Benz of Littleton    4.8  (1,216 reviews)   $54,426
# 207  Mercedes-Benz of Hoffman Estates    4.6  (1,210 reviews)   $50,999
# 208          Mercedes-Benz of Raleigh    5.0  (1,766 reviews)   $77,197
# 209                    RBM of Atlanta    4.2  (1,036 reviews)   $69,883
#
# [210 rows x 6 columns]

# %%
car_dealer['Review Count'] = car_dealer['Review Count'].apply(lambda x: x.strip('reviews)').strip('('))

# %%
car_dealer
# Out:
#                                         Name     Mileage  \
# 0    2020 Mercedes-Benz AMG C 43 Base 4MATIC  29,790 mi.
# 1          2023 Mercedes-Benz GLS 450 4MATIC  10,456 mi.
# 2     2020 Mercedes-Benz GLS 450 Base 4MATIC  38,260 mi.
# 3      2019 Mercedes-Benz AMG GT 63 S 4-Door   4,321 mi.
# 4    2021 Mercedes-Benz AMG C 43 Base 4MATIC  18,182 mi.
# ..                                       ...         ...
# 205         2022 Mercedes-Benz A-Class A 220  12,678 mi.
# 206       2023 Mercedes-Benz AMG GLB 35 Base   4,048 mi.
# 207       2023 Mercedes-Benz AMG GLB 35 Base   3,166 mi.
# 208  2023 Mercedes-Benz AMG C 43 Base 4MATIC   2,585 mi.
# 209    2021 Mercedes-Benz GLE 580 AWD 4MATIC  12,654 mi.
#
#                           Dealer Name Rating Review Count     Price
# 0        Mercedes-Benz of Kansas City    n/a          n/a   $47,698
# 1      Mercedes-Benz of Silver Spring    4.9       2,002    $83,900
# 2       Mercedes-Benz of White Plains    4.3       1,647    $54,924
# 3    Mercedes-Benz of Hoffman Estates    4.6       1,210   $125,999
# 4             Mercedes-Benz of Edison    5.0       4,416    $54,599
# ..                                ...    ...          ...       ...
# 205     Mercedes-Benz of West Houston    4.6          75    $33,893
# 206        Mercedes-Benz of Littleton    4.8       1,216    $54,426
# 207  Mercedes-Benz of Hoffman Estates    4.6       1,210    $50,999
# 208          Mercedes-Benz of Raleigh    5.0       1,766    $77,197
# 209                    RBM of Atlanta    4.2       1,036    $69,883
#
# [210 rows x 6 columns]
